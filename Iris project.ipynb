# %% [markdown]
# <b><h1>Iris flowers classification ML<b><h1>
#
# Data science-August202
#
# level-beginner
#
# by komal more

# %% [markdown]
# <b><h1>Importing Libraries<b><h1>
#
# Import in python is similar to #include header_file in C/C++. Python modules can get access to code from another module by importing the file/function using import.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os

# %%
import matplotlib as plt

# %%
from matplotlib import pyplot as plt

# %%
pwd
# Out:
# 'C:\\Users\\user\\Desktop\\Untitled Folder'

# %% [markdown]
#  <b><h1>loading the dataset<b><h1>
#
# The Load method provides a technique for filling a single DataTable with data, retrieved from an IDataReader instance. This method provides the same functionality

# %%
Iris_dataset=pd.read_csv('Iris.csv')

# %%
Iris_dataset
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#statistics about data
Iris_dataset.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
Iris_dataset.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#delete operation
Iris_dataset = Iris_dataset.drop(columns = ['Id'])
Iris_dataset.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
Iris_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
#sample of each class
Iris_dataset['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# <b><h1>Preprocessing the dataset<b><h1>
# Data Preprocessing is that step in which the data gets transformed, or Encoded, to bring it to such a state that now the machine can easily parse it

# %%
#check for null values
Iris_dataset.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# <b><h1> Exploratory data analysis<b><h1>
#
#     EDA is applied to investigate the data and summarize the key insights. It will give you the basic understanding of your data, it's distribution, null values and much more. You can either explore data using graphs or through some python functions.

# %%
#histograms
Iris_dataset['SepalLengthCm'].hist()
# Out:
# <AxesSubplot:>

# %%
Iris_dataset['SepalWidthCm'].hist()
# Out:
# <AxesSubplot:>

# %%
Iris_dataset['PetalLengthCm'].hist()
# Out:
# <AxesSubplot:>

# %%
Iris_dataset['PetalWidthCm'].hist()
# Out:
# <AxesSubplot:>

# %%
#scaterplot
colors=['red','black','orange']
species= ['Iris-setosa','Iris-versicolor','Iris-virginica']

# %%
for i in range(3):
    x= Iris_dataset[Iris_dataset['Species'] == species[i]]
    plt.scatter(x['SepalLengthCm'],x['SepalWidthCm'], c = colors[i],label=species[i])
    plt.xlabel("Sepal Length")
    plt.ylabel("Sepal Width")
    plt.legend()

# %%
for i in range(3):
    x= Iris_dataset[Iris_dataset['Species'] == species[i]]
    plt.scatter(x['PetalLengthCm'],x['PetalWidthCm'], c = colors[i],label=species[i])
    plt.xlabel("Petal Length")
    plt.ylabel("Petal Width")
    plt.legend()

# %%
for i in range(3):
    x= Iris_dataset[Iris_dataset['Species'] == species[i]]
    plt.scatter(x['SepalLengthCm'],x['PetalLengthCm'], c = colors[i],label=species[i])
    plt.xlabel("Sepal Length")
    plt.ylabel("Petal Length")
    plt.legend()

# %%
for i in range(3):
    x= Iris_dataset[Iris_dataset['Species'] == species[i]]
    plt.scatter(x['SepalWidthCm'],x['PetalWidthCm'], c = colors[i],label=species[i])
    plt.xlabel("Sepal width")
    plt.ylabel("Petal Width")
    plt.legend()

# %% [markdown]
# <b><h1>coorelation matrix<b><h1>
#
#     A correlation matrix is simply a table which displays the correlation coefficients for different variables. The matrix depicts the correlation between all the possible pairs of values in a table. It is a powerful tool to summarize a large dataset and to identify and visualize patterns in the given data

# %%
Iris_dataset.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
corr =Iris_dataset.corr()
fig, ax = plt.subplots(figsize=(6,5))
sns.heatmap(corr, annot=True, ax = ax)
# Out:
# <AxesSubplot:>

# %%
corr =Iris_dataset.corr()
fig, ax = plt.subplots(figsize=(6,5))
sns.heatmap(corr, annot=True, ax = ax, cmap = 'coolwarm')
# Out:
# <AxesSubplot:>

# %%
#boxplot
sns.boxplot(x="Species", y='PetalLengthCm', data=Iris_dataset)
plt.show()

# %%
sns.boxplot(x="Species", y='PetalWidthCm', data=Iris_dataset)
plt.show()

# %%
sns.boxplot(x="Species", y='SepalLengthCm', data=Iris_dataset)
plt.show()

# %%
sns.boxplot(x="Species", y='SepalWidthCm', data=Iris_dataset)
plt.show()

# %%
sns.pairplot(Iris_dataset,hue = 'Species')

# %% [markdown]
# <b><h1>label encode<b><h1>
#
# Label Encoding in Python can be achieved using Sklearn Library. Sklearn provides a very efficient tool for encoding the levels of categorical features into numeric values

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
Iris_dataset['Species'] = le.fit_transform(Iris_dataset['Species'])
Iris_dataset.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %% [markdown]
# <b><h1> model training<b><h1>
#
# Model training is the phase in the data science development lifecycle where practitioners try to fit the best combination of weights and bias to a machine learning algorithm to minimize a loss function over the prediction range.

# %%
from sklearn.model_selection import train_test_split
#train -70
# test - 30
X = Iris_dataset.drop(columns=['Species'])
Y = Iris_dataset['Species']
x_train, x_test,y_train, y_test= train_test_split(X,Y, test_size=0.30)

# %%
#logistic regressioin
from sklearn.linear_model import LogisticRegression
model= LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
#print metric to get performance
print("Accuracy:",model.score(x_test,y_test)*100)
# Out:
# Accuracy: 95.55555555555556

# %%
from sklearn.tree import DecisionTreeClassifier
model=  DecisionTreeClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Accuracy:",model.score(x_test,y_test)*100)
# Out:
# Accuracy: 95.55555555555556

# %%
#k-nearest neighbors
from sklearn.neighbors import KNeighborsClassifier
model=  KNeighborsClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
print("Accuracy:",model.score(x_test,y_test)*100)
# Out:
# Accuracy: 97.77777777777777

# %% [markdown]
# <b><h1>thankyou<b><h1>
